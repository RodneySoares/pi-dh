# %%
# IMPORTANDO BIBLIOTECAS
import pandas as pd

# %%
# IMPORTANDO DATASET
dataset = pd.read_parquet('dataset/row/hist_painel_covid_br_04_mai_2021.parquet.gzip', engine='auto')

# %%
# TIPOS DOS DADOS
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2270946 entries, 0 to 2270945
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   regiao                  object
#  1   estado                  object
#  2   municipio               object
#  3   coduf                   int64
#  4   codmun                  float64
#  5   codRegiaoSaude          float64
#  6   nomeRegiaoSaude         object
#  7   data                    object
#  8   semanaEpi               int64
#  9   populacaoTCU2019        float64
#  10  casosAcumulado          int64
#  11  casosNovos              int64
#  12  obitosAcumulado         int64
#  13  obitosNovos             int64
#  14  Recuperadosnovos        float64
#  15  emAcompanhamentoNovos   float64
#  16  interior/metropolitana  float64
# dtypes: float64(6), int64(6), object(5)
# memory usage: 294.5+ MB

# %%
# DESCRITIVO DOS DADOS
dataset.describe()
# Out:
#               coduf        codmun  codRegiaoSaude     semanaEpi  \
# count  2.270946e+06  2.258764e+06    2.250280e+06  2.270946e+06
# mean   3.235982e+01  3.252580e+05    3.240312e+04  2.606107e+01
# std    9.876054e+00  9.853505e+04    9.836343e+03  1.499472e+01
# min    1.100000e+01  1.100000e+05    1.100100e+04  1.000000e+00
# 25%    2.500000e+01  2.512000e+05    2.501000e+04  1.400000e+01
# 50%    3.100000e+01  3.146100e+05    3.105900e+04  2.500000e+01
# 75%    4.100000e+01  4.119150e+05    4.101500e+04  3.900000e+01
# max    7.600000e+01  5.300100e+05    5.300100e+04  5.300000e+01
#
#        populacaoTCU2019  casosAcumulado    casosNovos  obitosAcumulado  \
# count      2.262462e+06    2.270946e+06  2.270946e+06     2.270946e+06
# mean       1.185203e+05    2.994308e+03  1.962647e+01     8.166234e+01
# std        3.050972e+06    9.833367e+04  6.098975e+02     2.616443e+03
# min        7.810000e+02    0.000000e+00 -1.391500e+04     0.000000e+00
# ...

# %%
# DADOS NULOS
dataset.isnull().sum()
# Out:
# regiao                          0
# estado                        437
# municipio                   20666
# coduf                           0
# codmun                      12182
# codRegiaoSaude              20666
# nomeRegiaoSaude             20666
# data                            0
# semanaEpi                       0
# populacaoTCU2019             8484
# casosAcumulado                  0
# casosNovos                      0
# obitosAcumulado                 0
# obitosNovos                     0
# Recuperadosnovos          2270564
# emAcompanhamentoNovos     2270564
# interior/metropolitana      20666
# dtype: int64
