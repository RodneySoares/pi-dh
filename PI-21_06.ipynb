# %%
import pandas as pd
import seaborn as sns
import os
import numpy as np


data = pd.read_csv('C:/Users/daniu/Desktop/pi-dh/archive/brazil_covid19.csv')
data.head()
# Out:
#          date        region state  cases  deaths
# 0  2020-02-25  Centro-Oeste    DF    0.0       0
# 1  2020-02-25  Centro-Oeste    GO    0.0       0
# 2  2020-02-25  Centro-Oeste    MS    0.0       0
# 3  2020-02-25  Centro-Oeste    MT    0.0       0
# 4  2020-02-25      Nordeste    AL    0.0       0

# %%
import datetime
print(datetime.datetime.now())
today = datetime.datetime.now().strftime('%d/%m/%Y')
# Out:
# 2021-06-21 15:36:04.496138

# %%
data.tail()
# Out:
#              date   region state      cases  deaths
# 12253  2021-05-23  Sudeste    RJ   840480.0   49515
# 12254  2021-05-23  Sudeste    SP  3188105.0  107614
# 12255  2021-05-23      Sul    PR  1060683.0   25506
# 12256  2021-05-23      Sul    RS  1059990.0   27419
# 12257  2021-05-23      Sul    SC   947810.0   14822

# %%
print('Data de início do dataset: ' + min(data['date']))
print('Data do final do dataset: ' + max(data['date']))
# Out:
# Data de início do dataset: 2020-02-25
# Data do final do dataset: 2021-05-23

# %%
testes = pd.read_csv('C:/Users/daniu/Desktop/pi-dh/PI13_07/testes.csv')

# %%
testes
# Out:
#                         UF  Quantidade PCR  Quantidade teste rápido  \
# 0                       AC          159724                    77360
# 1                       AL          222856                   113220
# 2                       AM          349804                   181980
# 3                       AP          362128                    25240
# 4                       BA         1395320                   543900
# 5                       CE         1696304                   369960
# 6                       DF          436936                   388040
# 7   Doação para o exterior          134848                        0
# 8                       ES          184528                   222350
# 9                       GO          206344                   280760
# 10                      MA          310076                   261400
# 11                      MG         1089304                  2826920
# 12                      MS          557688                   114700
# ...

# %%
testes1 = pd.read_csv('https://github.com/RodneySoares/pi-dh/blob/main/dataset/testes.csv', sep='delimiter', header=None)
# Out:
# <ipython-input-14-575e0768b9b1>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   testes1 = pd.read_csv('https://github.com/RodneySoares/pi-dh/blob/main/dataset/testes.csv', sep='delimiter', header=None)

# %%
testes1
# Out:
#                                                       0
# 0                                       <!DOCTYPE html>
# 1     <html lang="en" data-color-mode="auto" data-li...
# 2                                                <head>
# 3                                <meta charset="utf-8">
# 4     <link rel="dns-prefetch" href="https://github....
# ...                                                 ...
# 1225                                  </clipboard-copy>
# 1226                                             </div>
# 1227                                        </template>
# 1228                                            </body>
# 1229                                            </html>
#
# [1230 rows x 1 columns]
